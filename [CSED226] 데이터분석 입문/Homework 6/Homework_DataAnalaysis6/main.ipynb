# %%
# import modules
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from sklearn.cluster import KMeans, DBSCAN, OPTICS
from sklearn.metrics import silhouette_score
from kmodes.kprototypes import KPrototypes
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
# age               : Int
# education         : Categorical
# education level   : Int
# marital status    : Categorical
# Occupation        : Catagorical
# relationship      : Categorical
# race              : Categorical
# sex               : Categorical
# Investment profit : Int, but almost all 0
# Investment loss   : Int, but almost all 0
# hours per week    : Int
# native country    : Categorical
# income            : Conditional (e.g. <=50k, >50k)

# %%
df = pd.read_csv('data/survey.csv')
df = df.drop(columns=['Investment profit', 'Investment loss'])
# for col in df.columns:
#     if col not in ['age', 'education level', 'Investment profit', 'Investment loss', 'hours per week']:
#         print(f'{col}: {df[col].unique()}')
#         print()

# %%
# K prototype clustering
print(df.columns)
k = 8
# kprototype init list: 'Huang', 'Cao', 'random'
Kp = KPrototypes(n_clusters=k, init='Cao', n_init=5, verbose=2)
Kp = Kp.fit(df, categorical=[1, 3, 4, 5, 6, 7, 9, 10])

# print(f'k={k} silhouette score: {silhouette_score(df, Kp.labels_)}')
submit = pd.DataFrame()
submit['ID'] = df.index
submit['label'] = Kp.labels_
submit.to_csv(f'kproto_{k}.csv', index=False)
# Out:
# Index(['age', 'education', 'education level', 'marital status', 'Occupation',
#        'relationship', 'race', 'sex', 'hours per week', 'native country',
#        'income'],
#       dtype='object')
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 2157, ncost: 685304.3682647109
# Run: 1, iteration: 2/100, moves: 912, ncost: 659193.8982308417
# Run: 1, iteration: 3/100, moves: 389, ncost: 655314.9712054264
# Run: 1, iteration: 4/100, moves: 266, ncost: 653232.799807809
# Run: 1, iteration: 5/100, moves: 144, ncost: 652470.4723786527
# Run: 1, iteration: 6/100, moves: 30, ncost: 652416.2246437569
# Run: 1, iteration: 7/100, moves: 10, ncost: 652406.4025125839
# Run: 1, iteration: 8/100, moves: 3, ncost: 652398.0393500621
# Run: 1, iteration: 9/100, moves: 4, ncost: 652391.2282390108
# Run: 1, iteration: 10/100, moves: 3, ncost: 652387.7664521054
# Run: 1, iteration: 11/100, moves: 12, ncost: 652375.6162277182
# Run: 1, iteration: 12/100, moves: 11, ncost: 652356.8910463915
# Run: 1, iteration: 13/100, moves: 8, ncost: 652348.7813161827
# Run: 1, iteration: 14/100, moves: 3, ncost: 652347.8370761006
# Run: 1, iteration: 15/100, moves: 3, ncost: 652347.3156508934
# Run: 1, iteration: 16/100, moves: 0, ncost: 652347.3156508934
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 2072, ncost: 743706.2273906169
# Run: 2, iteration: 2/100, moves: 1331, ncost: 703520.6291098216
# Run: 2, iteration: 3/100, moves: 1114, ncost: 663441.3502058443
# Run: 2, iteration: 4/100, moves: 779, ncost: 646284.7827077009
# Run: 2, iteration: 5/100, moves: 448, ncost: 640684.3413207029
# Run: 2, iteration: 6/100, moves: 405, ncost: 636053.9330603133
# Run: 2, iteration: 7/100, moves: 272, ncost: 634148.4568438792
# Run: 2, iteration: 8/100, moves: 148, ncost: 633582.915909544
# Run: 2, iteration: 9/100, moves: 115, ncost: 633300.0490332713
# Run: 2, iteration: 10/100, moves: 56, ncost: 633241.2645826439
# Run: 2, iteration: 11/100, moves: 14, ncost: 633236.9368109975
# Run: 2, iteration: 12/100, moves: 2, ncost: 633236.63114469
# Run: 2, iteration: 13/100, moves: 0, ncost: 633236.63114469
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 1347, ncost: 748680.1901897474
# Run: 3, iteration: 2/100, moves: 946, ncost: 724136.3107431898
# Run: 3, iteration: 3/100, moves: 765, ncost: 698959.2686977277
# Run: 3, iteration: 4/100, moves: 579, ncost: 678574.5879428916
# Run: 3, iteration: 5/100, moves: 425, ncost: 653659.169195963
# Run: 3, iteration: 6/100, moves: 454, ncost: 636273.2574743946
# Run: 3, iteration: 7/100, moves: 202, ncost: 633669.0166895809
# Run: 3, iteration: 8/100, moves: 58, ncost: 633389.2967856452
# Run: 3, iteration: 9/100, moves: 16, ncost: 633370.7648837848
# Run: 3, iteration: 10/100, moves: 8, ncost: 633351.2473106944
# Run: 3, iteration: 11/100, moves: 13, ncost: 633333.9373192197
# Run: 3, iteration: 12/100, moves: 4, ncost: 633330.1438019647
# Run: 3, iteration: 13/100, moves: 0, ncost: 633330.1438019647
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 2771, ncost: 725695.7066933953
# Run: 4, iteration: 2/100, moves: 1073, ncost: 675783.0825771074
# Run: 4, iteration: 3/100, moves: 551, ncost: 662657.033297557
# Run: 4, iteration: 4/100, moves: 335, ncost: 657648.7651446718
# Run: 4, iteration: 5/100, moves: 344, ncost: 654158.8292141237
# Run: 4, iteration: 6/100, moves: 283, ncost: 650433.0704141037
# Run: 4, iteration: 7/100, moves: 330, ncost: 644746.5324409229
# Run: 4, iteration: 8/100, moves: 317, ncost: 637676.2541785418
# Run: 4, iteration: 9/100, moves: 326, ncost: 628286.648902716
# Run: 4, iteration: 10/100, moves: 314, ncost: 621281.0474664727
# Run: 4, iteration: 11/100, moves: 273, ncost: 617488.0588015895
# Run: 4, iteration: 12/100, moves: 146, ncost: 616630.3838763299
# Run: 4, iteration: 13/100, moves: 161, ncost: 615203.5778100296
# Run: 4, iteration: 14/100, moves: 86, ncost: 614886.7138776539
# Run: 4, iteration: 15/100, moves: 44, ncost: 614755.0122352362
# Run: 4, iteration: 16/100, moves: 45, ncost: 614694.0801051358
# Run: 4, iteration: 17/100, moves: 17, ncost: 614682.5384027378
# Run: 4, iteration: 18/100, moves: 36, ncost: 614604.5012459831
# Run: 4, iteration: 19/100, moves: 109, ncost: 613964.8298849164
# Run: 4, iteration: 20/100, moves: 56, ncost: 613872.9410711585
# Run: 4, iteration: 21/100, moves: 22, ncost: 613820.7154582291
# Run: 4, iteration: 22/100, moves: 12, ncost: 613804.8439854136
# Run: 4, iteration: 23/100, moves: 14, ncost: 613790.2966437303
# Run: 4, iteration: 24/100, moves: 11, ncost: 613779.7355557893
# Run: 4, iteration: 25/100, moves: 6, ncost: 613777.0849852503
# Run: 4, iteration: 26/100, moves: 1, ncost: 613776.860055493
# Run: 4, iteration: 27/100, moves: 0, ncost: 613776.860055493
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 2885, ncost: 702819.5098684292
# Run: 5, iteration: 2/100, moves: 1120, ncost: 659489.9422053025
# Run: 5, iteration: 3/100, moves: 601, ncost: 641488.542467807
# Run: 5, iteration: 4/100, moves: 354, ncost: 630549.8873051718
# Run: 5, iteration: 5/100, moves: 349, ncost: 622210.5695966512
# Run: 5, iteration: 6/100, moves: 301, ncost: 618149.9206691134
# Run: 5, iteration: 7/100, moves: 204, ncost: 616801.2283169962
# Run: 5, iteration: 8/100, moves: 233, ncost: 614756.3941348462
# Run: 5, iteration: 9/100, moves: 72, ncost: 614466.8842427216
# Run: 5, iteration: 10/100, moves: 39, ncost: 614378.6794752231
# Run: 5, iteration: 11/100, moves: 95, ncost: 613822.2412700222
# Run: 5, iteration: 12/100, moves: 90, ncost: 613512.4785211805
# Run: 5, iteration: 13/100, moves: 69, ncost: 613344.2773364688
# Run: 5, iteration: 14/100, moves: 22, ncost: 613325.6241816945
# Run: 5, iteration: 15/100, moves: 3, ncost: 613324.1904070614
# Run: 5, iteration: 16/100, moves: 5, ncost: 613322.0136900425
# Run: 5, iteration: 17/100, moves: 1, ncost: 613321.3791894503
# Run: 5, iteration: 18/100, moves: 4, ncost: 613317.5776465215
# Run: 5, iteration: 19/100, moves: 5, ncost: 613313.9979685805
# Run: 5, iteration: 20/100, moves: 0, ncost: 613313.9979685805
# Best run was number 5

# %%
# Encoding
# LabelEncoders = {}
# for col in df.columns:
#     if col not in ['age', 'education level', 'Investment profit', 'Investment loss', 'hours per week']:
#         le = LabelEncoder()
#         df[col] = le.fit_transform(df[col])
#         LabelEncoders[col] = le

# Scaling
# scaler = MinMaxScaler()
# df[['age', 'education level', 'hours per week']] = scaler.fit_transform(df[['age', 'education level', 'hours per week']])

# %%
# k = 3
# kmeans = KMeans(n_clusters=k)
# kmeans.fit(df)
# print(f'k={k}, silhouette_score={silhouette_score(df, kmeans.labels_)}')
# submit = pd.DataFrame()
# submit['ID'] = df.index
# submit['Employment Type'] = kmeans.labels_
# submit.to_csv(f'kmeans_{k}.csv', index=False)
# Out:
# k=3, silhouette_score=0.32110355601844065
