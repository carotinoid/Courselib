# %%
# import modules
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from sklearn.cluster import KMeans, DBSCAN, OPTICS
from sklearn.metrics import silhouette_score
from kmodes.kprototypes import KPrototypes
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
# age               : Int
# education         : Categorical
# education level   : Int
# marital status    : Categorical
# Occupation        : Catagorical
# relationship      : Categorical
# race              : Categorical
# sex               : Categorical
# Investment profit : Int, but almost all 0
# Investment loss   : Int, but almost all 0
# hours per week    : Int
# native country    : Categorical
# income            : Conditional (e.g. <=50k, >50k)

# %%
df = pd.read_csv('data/survey.csv')
df = df.drop(columns=['Investment profit', 'Investment loss'])
# for col in df.columns:
#     if col not in ['age', 'education level', 'Investment profit', 'Investment loss', 'hours per week']:
#         print(f'{col}: {df[col].unique()}')
#         print()

# %%
# K prototype clustering
print(df.columns)
k = 3
Kp = KPrototypes(n_clusters=k, init='Huang', n_init=10, verbose=2)
Kp = Kp.fit(df, categorical=[1, 3, 4, 5, 6, 7, 9, 10])

# print(f'k={k} silhouette score: {silhouette_score(df, Kp.labels_)}')
submit = pd.DataFrame()
submit['ID'] = df.index
submit['label'] = Kp.labels_
submit.to_csv(f'kproto_{k}.csv', index=False)
# Out:
# Index(['age', 'education', 'education level', 'marital status', 'Occupation',
#        'relationship', 'race', 'sex', 'hours per week', 'native country',
#        'income'],
#       dtype='object')
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 1770, ncost: 1632427.4951277676
# Run: 1, iteration: 2/100, moves: 879, ncost: 1545874.7762323061
# Run: 1, iteration: 3/100, moves: 397, ncost: 1526168.7123899632
# Run: 1, iteration: 4/100, moves: 183, ncost: 1521619.1609387433
# Run: 1, iteration: 5/100, moves: 68, ncost: 1520944.8668016752
# Run: 1, iteration: 6/100, moves: 47, ncost: 1520571.090572126
# Run: 1, iteration: 7/100, moves: 64, ncost: 1520241.4636084996
# Run: 1, iteration: 8/100, moves: 78, ncost: 1519508.5355285262
# Run: 1, iteration: 9/100, moves: 80, ncost: 1519106.0652363421
# Run: 1, iteration: 10/100, moves: 23, ncost: 1519002.1316697076
# Run: 1, iteration: 11/100, moves: 12, ncost: 1518986.1425052274
# Run: 1, iteration: 12/100, moves: 3, ncost: 1518985.209974442
# Run: 1, iteration: 13/100, moves: 0, ncost: 1518985.209974442
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 2273, ncost: 1589755.3436020326
# Run: 2, iteration: 2/100, moves: 652, ncost: 1535505.7515627695
# Run: 2, iteration: 3/100, moves: 254, ncost: 1524148.8567020756
# Run: 2, iteration: 4/100, moves: 144, ncost: 1521325.9782019781
# Run: 2, iteration: 5/100, moves: 54, ncost: 1520889.5127940646
# Run: 2, iteration: 6/100, moves: 43, ncost: 1520530.5463986224
# Run: 2, iteration: 7/100, moves: 62, ncost: 1520229.4636950984
# Run: 2, iteration: 8/100, moves: 75, ncost: 1519508.5355285262
# Run: 2, iteration: 9/100, moves: 80, ncost: 1519106.0652363421
# Run: 2, iteration: 10/100, moves: 23, ncost: 1519002.1316697076
# Run: 2, iteration: 11/100, moves: 12, ncost: 1518986.1425052274
# Run: 2, iteration: 12/100, moves: 3, ncost: 1518985.209974442
# Run: 2, iteration: 13/100, moves: 0, ncost: 1518985.209974442
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 1119, ncost: 1408576.349314976
# Run: 3, iteration: 2/100, moves: 547, ncost: 1388546.7955834856
# Run: 3, iteration: 3/100, moves: 266, ncost: 1384334.8750607753
# Run: 3, iteration: 4/100, moves: 56, ncost: 1384182.7456613458
# Run: 3, iteration: 5/100, moves: 16, ncost: 1384164.4869030742
# Run: 3, iteration: 6/100, moves: 1, ncost: 1384164.3798774756
# Run: 3, iteration: 7/100, moves: 0, ncost: 1384164.3798774756
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 674, ncost: 1675852.9274622712
# Run: 4, iteration: 2/100, moves: 858, ncost: 1584114.7338680893
# Run: 4, iteration: 3/100, moves: 418, ncost: 1547859.483916513
# Run: 4, iteration: 4/100, moves: 257, ncost: 1527795.274849718
# Run: 4, iteration: 5/100, moves: 171, ncost: 1522193.3732058455
# Run: 4, iteration: 6/100, moves: 84, ncost: 1521035.5504521453
# Run: 4, iteration: 7/100, moves: 30, ncost: 1520865.8656615175
# Run: 4, iteration: 8/100, moves: 46, ncost: 1520449.0079876925
# Run: 4, iteration: 9/100, moves: 60, ncost: 1520217.964969993
# Run: 4, iteration: 10/100, moves: 112, ncost: 1519193.4781461402
# Run: 4, iteration: 11/100, moves: 47, ncost: 1519042.1967100806
# Run: 4, iteration: 12/100, moves: 18, ncost: 1518990.4567994596
# Run: 4, iteration: 13/100, moves: 6, ncost: 1518986.1425052274
# Run: 4, iteration: 14/100, moves: 3, ncost: 1518985.209974442
# Run: 4, iteration: 15/100, moves: 0, ncost: 1518985.209974442
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 1972, ncost: 1467891.4687578273
# Run: 5, iteration: 2/100, moves: 1113, ncost: 1394120.6055558727
# Run: 5, iteration: 3/100, moves: 421, ncost: 1385343.590081707
# Run: 5, iteration: 4/100, moves: 144, ncost: 1384230.8416910216
# Run: 5, iteration: 5/100, moves: 16, ncost: 1384204.1967221552
# Run: 5, iteration: 6/100, moves: 15, ncost: 1384183.045671999
# Run: 5, iteration: 7/100, moves: 15, ncost: 1384162.4993669812
# Run: 5, iteration: 8/100, moves: 8, ncost: 1384147.6900482844
# Run: 5, iteration: 9/100, moves: 5, ncost: 1384144.5536729628
# Run: 5, iteration: 10/100, moves: 0, ncost: 1384144.5536729628
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/100, moves: 1529, ncost: 1422473.5389805608
# Run: 6, iteration: 2/100, moves: 801, ncost: 1390795.0796697133
# Run: 6, iteration: 3/100, moves: 287, ncost: 1384680.4537539606
# Run: 6, iteration: 4/100, moves: 77, ncost: 1384180.4104779959
# Run: 6, iteration: 5/100, moves: 17, ncost: 1384152.063904149
# Run: 6, iteration: 6/100, moves: 2, ncost: 1384151.4513727452
# Run: 6, iteration: 7/100, moves: 0, ncost: 1384151.4513727452
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/100, moves: 1189, ncost: 1646091.5713703274
# Run: 7, iteration: 2/100, moves: 632, ncost: 1622976.5524434354
# Run: 7, iteration: 3/100, moves: 317, ncost: 1604082.8369954093
# Run: 7, iteration: 4/100, moves: 304, ncost: 1577773.392453339
# Run: 7, iteration: 5/100, moves: 320, ncost: 1549434.3752798645
# Run: 7, iteration: 6/100, moves: 279, ncost: 1528790.908307289
# Run: 7, iteration: 7/100, moves: 165, ncost: 1522539.9844961534
# Run: 7, iteration: 8/100, moves: 103, ncost: 1521042.7145423458
# Run: 7, iteration: 9/100, moves: 31, ncost: 1520865.8656615175
# Run: 7, iteration: 10/100, moves: 46, ncost: 1520449.0079876925
# Run: 7, iteration: 11/100, moves: 60, ncost: 1520217.964969993
# Run: 7, iteration: 12/100, moves: 112, ncost: 1519193.4781461402
# Run: 7, iteration: 13/100, moves: 47, ncost: 1519042.1967100806
# Run: 7, iteration: 14/100, moves: 18, ncost: 1518990.4567994596
# Run: 7, iteration: 15/100, moves: 6, ncost: 1518986.1425052274
# Run: 7, iteration: 16/100, moves: 3, ncost: 1518985.209974442
# Run: 7, iteration: 17/100, moves: 0, ncost: 1518985.209974442
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/100, moves: 958, ncost: 1554165.8017177784
# Run: 8, iteration: 2/100, moves: 433, ncost: 1529392.3721278792
# Run: 8, iteration: 3/100, moves: 185, ncost: 1521820.9883083054
# Run: 8, iteration: 4/100, moves: 131, ncost: 1519715.1998159348
# Run: 8, iteration: 5/100, moves: 65, ncost: 1519161.846382113
# Run: 8, iteration: 6/100, moves: 15, ncost: 1519116.9786316657
# Run: 8, iteration: 7/100, moves: 6, ncost: 1519107.283350023
# Run: 8, iteration: 8/100, moves: 0, ncost: 1519107.283350023
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/100, moves: 1243, ncost: 1465980.8496957798
# Run: 9, iteration: 2/100, moves: 990, ncost: 1392147.1429712558
# Run: 9, iteration: 3/100, moves: 428, ncost: 1383715.4704468483
# Run: 9, iteration: 4/100, moves: 73, ncost: 1383385.047339398
# Run: 9, iteration: 5/100, moves: 28, ncost: 1383335.8509608447
# Run: 9, iteration: 6/100, moves: 6, ncost: 1383331.8687331546
# Run: 9, iteration: 7/100, moves: 0, ncost: 1383331.8687331546
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/100, moves: 1190, ncost: 1482622.8702792963
# Run: 10, iteration: 2/100, moves: 635, ncost: 1460675.0615833031
# Run: 10, iteration: 3/100, moves: 476, ncost: 1448351.5585585923
# Run: 10, iteration: 4/100, moves: 568, ncost: 1422355.1249646766
# Run: 10, iteration: 5/100, moves: 623, ncost: 1387720.8240654566
# Run: 10, iteration: 6/100, moves: 197, ncost: 1384746.6370825947
# Run: 10, iteration: 7/100, moves: 79, ncost: 1384238.8657667523
# Run: 10, iteration: 8/100, moves: 18, ncost: 1384204.1967221552
# Run: 10, iteration: 9/100, moves: 15, ncost: 1384183.045671999
# Run: 10, iteration: 10/100, moves: 15, ncost: 1384162.4993669812
# Run: 10, iteration: 11/100, moves: 8, ncost: 1384147.6900482844
# Run: 10, iteration: 12/100, moves: 5, ncost: 1384144.5536729628
# Run: 10, iteration: 13/100, moves: 0, ncost: 1384144.5536729628
# Best run was number 9

# %%
# Encoding
# LabelEncoders = {}
# for col in df.columns:
#     if col not in ['age', 'education level', 'Investment profit', 'Investment loss', 'hours per week']:
#         le = LabelEncoder()
#         df[col] = le.fit_transform(df[col])
#         LabelEncoders[col] = le

# Scaling
# scaler = MinMaxScaler()
# df[['age', 'education level', 'hours per week']] = scaler.fit_transform(df[['age', 'education level', 'hours per week']])

# %%
# k = 3
# kmeans = KMeans(n_clusters=k)
# kmeans.fit(df)
# print(f'k={k}, silhouette_score={silhouette_score(df, kmeans.labels_)}')
# submit = pd.DataFrame()
# submit['ID'] = df.index
# submit['Employment Type'] = kmeans.labels_
# submit.to_csv(f'kmeans_{k}.csv', index=False)
# Out:
# k=3, silhouette_score=0.32110355601844065
